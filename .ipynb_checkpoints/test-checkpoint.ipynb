# %% [markdown]
# ## translation by gummy

# %%
from gummy import TranslationGummy
from gummy.utils import get_driver

# %%
with get_driver() as driver:          
    model = TranslationGummy(driver=driver, gateway="useless", translator="deepl")
    pdf_path = model.toPDF(url="https://academic.oup.com/brain/article/142/7/1905/5506062")
    print(pdf_path)
# Out:
# Estimated Journal Type : OxfordAcademic
# Crawling Type: soup
# Use UselessGateWay._pass2others method.
# Wait up to 3[s] for all page elements to load.
# Scroll down to the bottom of the page.
#
# Decompose unnecessary tags.
# ==============================
# Decomposed <link> tag (21)
# Decomposed <meta> tag (163)
# Decomposed <noscript> tag (3)
# Decomposed <script> tag (38)
# Decomposed <style> tag (12)
# Decomposed <sup> tag (0)
# Decomposed <None> tag (0)
#
# Show contents of the paper.
# ==============================
# [1/1] Abstract
#
# Translation: DeepL
# ==============================
# [1/1] Abstract (query1) 05/30[###-----------------] 16.67% - 5.872[s]   translated: RNA干渉
# Save HTML file at /Users/hakureishi/.gummy/Allele-specific silencing as treatment for gene duplication disorders proof-of-principle in autosomal dominant leukodystrophy.html
#
# Convert from HTML to PDF
# ==============================
# Loading pages (1/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Printing pages (6/6)
# Done
# Save PDF file at /Users/hakureishi/.gummy/Allele-specific silencing as treatment for gene duplication disorders proof-of-principle in autosomal dominant leukodystrophy.pdf
# Delete original HTML file at /Users/hakureishi/.gummy/Allele-specific silencing as treatment for gene duplication disorders proof-of-principle in autosomal dominant leukodystrophy.html
# /Users/hakureishi/.gummy/Allele-specific silencing as treatment for gene duplication disorders proof-of-principle in autosomal dominant leukodystrophy.pdf

# %% [markdown]
# ## Post arxiv articles to slack with translationGummy

# %%
import re
import requests
import pickle
import os
import datetime
from gummy.cli import translate_journal


def parse(data, tag):
    # parse atom file
    # e.g. Input :<tag>XYZ </tag> -> Output: XYZ

    pattern = "<" + tag + ">([\s\S]*?)<\/" + tag + ">"
    if all:
        obj = re.findall(pattern, data)
    return obj


api_url_slack =

def search_and_send(query, start, ids, api_url):
    while True:
        counter = 0
        # url of arXiv API
        # If you want to customize, please change here.
        # detail is shown here, https://arxiv.org/help/api/user-manual
        url = 'http://export.arxiv.org/api/query?search_query=submittedDate:[' + previousdate.strftime(
            '%Y%m%d') + '0000+TO+' + basedate.strftime('%Y%m%d') + '0000]+AND+' + query
        # Get returned value from arXiv API
        data = requests.get(url).text
        # Parse the returned value
        entries = parse(data, "entry")
        for entry in entries:
            # Parse each entry
            url = parse(entry, "id")[0]
            
            #print(url)
            
            if not(url in ids):
                title = parse(entry, "title")[0]
                # abstract = parse(entry, "summary")[0]
                date = parse(entry, "published")[0]
                #post to slack
                message = "\n".join(["=" * 10, "No." + str(counter + 1), "Title:  " + title, "URL: " + url, "Published: " + date])
                requests.post(api_url, json={"text": message})
                #translation by gummy
                savefolder =
                translate_journal([str(url), '-pdf',savefolder+title +'.pdf'])
                
                ids.append(url)
                counter = counter + 1
                #if counter == 10:
                if counter == 2:
                    return 0
        if counter == 0 and len(entries) < 100:
            requests.post(api_url, json={"text": "Currently, there is no available papers"})
            return 0
        elif counter == 0 and len(entries) == 100:
            # When there is no available paper and full query
            start = start + 100


if __name__ == "__main__":
    basedate = datetime.date.today()
    previousdate = basedate + datetime.timedelta(days=-5)
    print("Publish")
    # Set URL of API
    # Please change here
    api_url = api_url_slack
    # Load log of published data
    if os.path.exists("published.pkl"):
        ids = pickle.load(open("published.pkl",'rb'))
    else:
        ids = []
    # Query for arXiv API
    # Please change here
    query = "((abs:spin-orbit torque)+OR+(abs:spin-torque)" + \
           "+OR+(abs:orbital Hall)+ OR + (abs:spintronics)+ OR + (abs:Rashba-Edelstein)" \
            "+ OR + (abs:spin Hall)+ OR + (abs:Rashba))"    
    #query = "(abs:spin-orbit torque)"
    start = 0
    # Post greeting to your Slack
    requests.post(api_url, json={"text": "Hello!!"})
    # Call function
    search_and_send(query, start, ids, api_url)
    # Update log of published data
    pickle.dump(ids, open("published.pkl", "wb"))
# Out:
# Publish
# Estimated Journal Type : arXiv
# Crawling Type: pdf
# HTTP Error 404: Not Found : url=https://arxiv.org/pdf/http://arxiv.org/abs/2102.05837v1.pdf
# Try to download using webdriver (Open Browser)
# Downloading PDF from https://arxiv.org/pdf/http://arxiv.org/abs/2102.05837v1.pdf
# Save PDF at /Users/hakureishi/.gummy/2102.06566.pdf
# Get HTML content from https://arxiv.org/abs/http://arxiv.org/abs/2102.05837v1
#
# Decompose unnecessary tags.
# ==============================
# Decomposed <link> tag (4)
# Decomposed <meta> tag (1)
# Decomposed <noscript> tag (0)
# Decomposed <script> tag (2)
# Decomposed <style> tag (0)
# Decomposed <sup> tag (0)
# Decomposed <None> tag (0)
# Page.01/10
# Page.02/10
# Page.03/10
# Page.04/10
# Page.05/10
# Page.06/10
# Page.07/10
# Page.08/10
# Page.09/10
# Page.10/10
#
# Translation: DeepL
# ==============================
# [01/10] Page.01/10 (query1) 15/30[##########----------] 50.00% - 18.502[s]   translated: Power
# [02/10] Page.02/10 (query1) 08/30[#####---------------] 26.67% - 9.283[s]   translated: Page
# [03/10] Page.03/10 (query1) 30/30[####################]100.00% - 33.397[s]   translated:
# [04/10] Page.04/10 (query1) 30/30[####################]100.00% - 33.476[s]   translated:
# [04/10] Page.04/10 (query2) 04/30[##------------------] 13.33% - 4.605[s]   translated: (a) S
# [05/10] Page.05/10 (query1) 03/30[##------------------] 10.00% - 3.285[s]   translated: これは、t
# [06/10] Page.06/10 (query1) 30/30[####################]100.00% - 34.954[s]   translated:
# [07/10] Page.07/10 (query1) 30/30[####################]100.00% - 35.435[s]   translated:
# [08/10] Page.08/10 (query1) 30/30[####################]100.00% - 33.723[s]   translated:
# [09/10] Page.09/10 (query1) 30/30[####################]100.00% - 34.258[s]   translated:
# [10/10] Page.10/10 (query1) 30/30[####################]100.00% - 35.925[s]   translated:
# Save HTML file at /Users/hakureishi/Google ドライブ/gummyPaperLarge topological Hall effect near room temperature in noncollinear ferromagnet LaMn2Ge2 single crystal.html
#
# Convert from HTML to PDF
# ==============================
# Loading pages (1/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Printing pages (6/6)
# Done
# Save PDF file at /Users/hakureishi/Google ドライブ/gummyPaperLarge topological Hall effect near room temperature in noncollinear ferromagnet LaMn2Ge2 single crystal.pdf
# Delete original HTML file at /Users/hakureishi/Google ドライブ/gummyPaperLarge topological Hall effect near room temperature in noncollinear ferromagnet LaMn2Ge2 single crystal.html
# Estimated Journal Type : arXiv
# Crawling Type: pdf
# HTTP Error 404: Not Found : url=https://arxiv.org/pdf/http://arxiv.org/abs/2102.06302v1.pdf
# Try to download using webdriver (Open Browser)
# Downloading PDF from https://arxiv.org/pdf/http://arxiv.org/abs/2102.06302v1.pdf
# Save PDF at /Users/hakureishi/.gummy/2102.06566.pdf
# Get HTML content from https://arxiv.org/abs/http://arxiv.org/abs/2102.06302v1
#
# Decompose unnecessary tags.
# ==============================
# Decomposed <link> tag (4)
# Decomposed <meta> tag (1)
# Decomposed <noscript> tag (0)
# Decomposed <script> tag (2)
# Decomposed <style> tag (0)
# Decomposed <sup> tag (0)
# Decomposed <None> tag (0)
# Page.01/10
# Page.02/10
# Page.03/10
# Page.04/10
# Page.05/10
# Page.06/10
# Page.07/10
# Page.08/10
# Page.09/10
# Page.10/10
#
# Translation: DeepL
# ==============================
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-30-cd01ab49a42b> in <module>
#      83     requests.post(api_url, json={"text": "Hello!!"})
#      84     # Call function
# ---> 85     search_and_send(query, start, ids, api_url)
#      86     # Update log of published data
#      87     pickle.dump(ids, open("published.pkl", "wb"))
#
# <ipython-input-30-cd01ab49a42b> in search_and_send(query, start, ids, api_url)
#      46                 #translation by gummy
#      47                 savefolder = '/Users/hakureishi/Google ドライブ/gummyPaper'
# ---> 48                 translate_journal([str(url), '-pdf',savefolder+title +'.pdf'])
#      49
#      50                 ids.append(url)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/cli.py in translate_journal(argv)
#      96         verbose=verbose, translator_verbose=translator_verbose,
#      97     )
# ---> 98     pdf_path = model.toPDF(
#      99         url=url, path=pdf_path, out_dir=out_dir, correspond=correspond,
#     100         journal_type=journal_type, crawl_type=crawl_type, gateway=gateway,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py in toPDF(self, url, path, out_dir, from_lang, to_lang, correspond, journal_type, crawl_type, gateway, searchpath, template, delete_html, options, **gatewaykwargs)
#     179             gatewaykwargs (dict)        : Gateway keywargs. See :meth:`passthrough <gummy.gateways.GummyAbstGateWay.passthrough>`.
#     180         """
# --> 181         htmlpath = self.toHTML(
#     182             url=url, path=path, out_dir=out_dir,
#     183             from_lang=from_lang, to_lang=to_lang, correspond=correspond,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py in toHTML(self, url, path, out_dir, from_lang, to_lang, correspond, journal_type, crawl_type, gateway, searchpath, template, **gatewaykwargs)
#     146             barname = f"[{i+1:>0{len(str(len_contents))}}/{len_contents}] " + toACCENT(content.get("head","\t"))
#     147             if "raw" in content:
# --> 148                 content["raw"], content["translated"] = self.translator.translate_wrapper(query=content["raw"], barname=barname, from_lang=from_lang, to_lang=to_lang, correspond=correspond)
#     149             elif "img" in content and self.verbose:
#     150                 print(barname + "<img>")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/translators.py in translate_wrapper(self, query, driver, barname, from_lang, to_lang, correspond)
#     260             handleKeyError(lst=list(self.lang2args[from_lang].keys()), to_lang=to_lang)
#     261             find_translated_bulk, find_translated_corr, is_translated_properly, url_fmt = self.specialize2langs(from_lang, to_lang)
# --> 262         return self._translate(query=query, find_translated_bulk=find_translated_bulk, find_translated_corr=find_translated_corr, is_translated_properly=is_translated_properly, url_fmt=url_fmt, driver=driver, barname=barname)
#     263
#     264     def _translate(self, query, find_translated_bulk, find_translated_corr, is_translated_properly, url_fmt, correspond=True, driver=None, barname=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/translators.py in _translate(self, query, find_translated_bulk, find_translated_corr, is_translated_properly, url_fmt, correspond, driver, barname)
#     277             tuple : SourceSentences ( ``list`` ) , TargetSentences ( ``list`` ) .
#     278         """
# --> 279         driver = self.check_driver(driver=driver)
#     280         barname = barname or self.class_name
#     281         SourceSentences = []; TargetSentences = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/translators.py in check_driver(self, driver)
#     110         driver = driver or self.driver
#     111         if driver is None:
# --> 112             driver = get_driver()
#     113         self.driver = driver
#     114         # if self.verbose: print(f"Driver info:\n{json.dumps(self.driver_info, indent=2)}")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py in get_driver(driver_type, chrome_options, browser, selenium_port)
#     128     handleKeyError(lst=SUPPORTED_DRIVER_TYPES, driver_type=driver_type)
#     129     if chrome_options is None: chrome_options = get_chrome_options(browser=browser)
# --> 130     return eval(f"_get_driver_{driver_type}(chrome_options, selenium_port=selenium_port)")
#     131
#     132 def try_find_element(driver, by, identifier, timeout=3, verbose=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py in <module>
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py in _get_driver_local(chrome_options, **kwargs)
#      88
#      89 def _get_driver_local(chrome_options, **kwargs):
# ---> 90     driver = webdriver.Chrome(options=chrome_options)
#      91     return driver
#      92
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def parse(data, tag):
    # parse atom file
    # e.g. Input :<tag>XYZ </tag> -> Output: XYZ
    pattern = "<" + tag + ">([\s\S]*?)<\/" + tag + ">"
    if all:
        obj = re.findall(pattern, data)
    return obj

# %%
#url = 'http://arxiv.org/abs/2102.06279v1'
url=
from gummy.cli import translate_journal
savefolder =
title = 'a'
translate_journal([str(url), '-pdf',savefolder+title +'.pdf'])
# Out:
# Crawling Type: pdf
# Page.1/1
#
# Translation: DeepL
# ==============================
# [1/1] Page.1/1 (query1) 11/30[#######-------------] 36.67% - 12.344[s]   translated: www.n
# [1/1] Page.1/1 (query2) 03/30[##------------------] 10.00% - 3.508[s]   translated: 強誘電体分
# Save HTML file at /Users/hakureishi/Desktop/a.html
#
# Convert from HTML to PDF
# ==============================
# Loading pages (1/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Warning: Failed to load https://use.fontawesome.com/releases/v5.6.1/css/all.css (ignore)
# Printing pages (6/6)
# Done
# Save PDF file at /Users/hakureishi/Desktop/a.pdf
# Delete original HTML file at /Users/hakureishi/Desktop/a.html
# '/Users/hakureishi/Desktop/a.pdf'

# %% [markdown]
# ## delete messages

# %%
#coding: utf-8

import urllib.request
import urllib.parse
import json
import time

hist_url = "https://slack.com/api/conversations.history"
delete_url = "https://slack.com/api/chat.delete"

token = 
channel = 

hist_params = {
    'channel' : channel,
    'token' : token,
    'count' : '1'
}

req = urllib.request.Request(hist_url)
hist_params = urllib.parse.urlencode(hist_params).encode('ascii')
req.data = hist_params

res = urllib.request.urlopen(req)

body = res.read()
data = json.loads(body)
print(data)
# Out:
# {'ok': False, 'error': 'not_in_channel'}

# %%
for m in data['messages']:
    print(m)
    delete_params = {
        'channel' : channel,
        'token' : token,
        'ts' :  m["ts"]
    }
    req = urllib.request.Request(delete_url)
    delete_params = urllib.parse.urlencode(delete_params).encode('ascii')
    req.data = delete_params

    res = urllib.request.urlopen(req)
    body = res.read()

    print(body)
    time.sleep(2)
# Out:
# -----------------------------------------------------------------------
# KeyError                              Traceback (most recent call last)
# <ipython-input-43-46d5ccdb92a8> in <module>
# ----> 1 for m in data['messages']:
#       2     print(m)
#       3     delete_params = {
#       4         'channel' : channel,
#       5         'token' : token,
#
# KeyError: 'messages'

# %%
"""Delete old Slack messages at specific channel."""
from datetime import datetime
from time import sleep
import json
import re
import sys
import urllib.parse
import urllib.request

DELETE_URL = "https://slack.com/api/chat.delete"
HISTORY_URL = "https://slack.com/api/conversations.history"
#API_TOKEN = 


#TERM = 60 * 60 * 24 * 7  # 1 week
TERM = 60 * 60 * 24   # 1 day 

def clean_old_message(channel_id):
    print('Start cleaning message at channel "{}".'.format(channel_id))
    current_ts = int(datetime.now().strftime('%s'))
    messages = get_message_history(channel_id)
    print(messages)
    for message in messages:
        if current_ts - int(re.sub(r'\.\d+$', '', message['ts'])) > TERM:
            delete_message(channel_id, message['ts'])
            sleep(1)


def get_message_history(channel_id, count=800):
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    params = {
        'token': API_TOKEN,
        'channel': channel_id,
        'count': str(count)
    }

    req_url = '{}?{}'.format(HISTORY_URL, urllib.parse.urlencode(params))
    req = urllib.request.Request(req_url, headers=headers)

    message_history = []
    with urllib.request.urlopen(req) as res:
        data = json.loads(res.read().decode("utf-8"))
        if 'messages' in data:
            message_history = data['messages']

    return message_history


def delete_message(channel_id, message_ts):
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    params = {
        'token': API_TOKEN,
        'channel': channel_id,
        'ts': message_ts
    }

    req_url = '{}?{}'.format(DELETE_URL, urllib.parse.urlencode(params))
    req = urllib.request.Request(req_url, headers=headers)
    with urllib.request.urlopen(req) as res:
        data = json.loads(res.read().decode("utf-8"))
        if 'ok' not in data or data['ok'] is not True:
            print('Failed to delete message. ts: {}'.format(message_ts))

# %%
# Out:
# Start cleaning message at channel "CJAB1N7DM".
# [{'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.2\nTitle:  Orbital Frustration and Emergent Flat Bands\nURL: <http://arxiv.org/abs/2102.06302v1>\nPublished: 2021-02-11T23:01:47Z', 'ts': '1613373914.002200', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.1\nTitle:  Large topological Hall effect near room temperature in noncollinear\n  ferromagnet LaMn2Ge2 single crystal\nURL: <http://arxiv.org/abs/2102.05837v1>\nPublished: 2021-02-11T04:07:08Z', 'ts': '1613373574.002100', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613373573.002000', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Currently, there is no available papers', 'ts': '1613372416.001900', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613372415.001800', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Currently, there is no available papers', 'ts': '1613372406.001700', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.1\nTitle:  kPAM 2.0: Feedback Control for Category-Level Robotic Manipulation\nURL: <http://arxiv.org/abs/2102.06279v1>\nPublished: 2021-02-11T21:36:10Z', 'ts': '1613372404.001600', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613372403.001500', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.2\nTitle:  Hot Jupiters: Origins, Structure, Atmospheres\nURL: <http://arxiv.org/abs/2102.05064v2>\nPublished: 2021-02-09T19:00:12Z', 'ts': '1613372044.001400', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.1\nTitle:  Preventing Anomalous Torques in Circumbinary Accretion Simulations\nURL: <http://arxiv.org/abs/2102.05684v1>\nPublished: 2021-02-10T19:00:16Z', 'ts': '1613372043.001300', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613372041.001200', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.2\nTitle:  Hot Jupiters: Origins, Structure, Atmospheres\nURL: <http://arxiv.org/abs/2102.05064v2>\nPublished: 2021-02-09T19:00:12Z', 'ts': '1613371580.001100', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.1\nTitle:  Preventing Anomalous Torques in Circumbinary Accretion Simulations\nURL: <http://arxiv.org/abs/2102.05684v1>\nPublished: 2021-02-10T19:00:16Z', 'ts': '1613371580.001000', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613371578.000900', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.2\nTitle:  Hot Jupiters: Origins, Structure, Atmospheres\nURL: <http://arxiv.org/abs/2102.05064v2>\nPublished: 2021-02-09T19:00:12Z', 'ts': '1613371065.000800', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': '==========\nNo.1\nTitle:  Preventing Anomalous Torques in Circumbinary Accretion Simulations\nURL: <http://arxiv.org/abs/2102.05684v1>\nPublished: 2021-02-10T19:00:16Z', 'ts': '1613371064.000700', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subtype': 'bot_message', 'text': 'Hello!!', 'ts': '1613371063.000600', 'username': 'incoming-webhook', 'bot_id': 'BJ8GJHATA'}, {'type': 'message', 'subt ...

# %% [markdown]
# ## post arxiv articles and delete privious posts on slack

# %%
from datetime import datetime
from time import sleep
import json
import re
import sys
import urllib.parse
import urllib.request
import requests
import pickle
import os
import datetime
from gummy.cli import translate_journal
import passes


DELETE_URL = "https://slack.com/api/chat.delete"
HISTORY_URL = "https://slack.com/api/conversations.history"


#TERM = 60 * 60 * 24 * 7  # 1 week
TERM = 60 * 60 * 24 * 2   # 2 day 

def clean_old_message(channel_id):
    print('Start cleaning message at channel "{}".'.format(channel_id))
    current_ts = int(datetime.now().strftime('%s'))
    messages = get_message_history(channel_id)
    print(messages)
    for message in messages:
        if current_ts - int(re.sub(r'\.\d+$', '', message['ts'])) > TERM:
            delete_message(channel_id, message['ts'])
            sleep(1)


def get_message_history(channel_id, count=800):
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    params = {
        'token': passes.API_TOKEN, #save in passes.py
        'channel': channel_id,
        'count': str(count)
    }

    req_url = '{}?{}'.format(HISTORY_URL, urllib.parse.urlencode(params))
    req = urllib.request.Request(req_url, headers=headers)

    message_history = []
    with urllib.request.urlopen(req) as res:
        data = json.loads(res.read().decode("utf-8"))
        if 'messages' in data:
            message_history = data['messages']

    return message_history


def delete_message(channel_id, message_ts):
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    params = {
        'token': passes.API_TOKEN, #save in passes.py
        'channel': channel_id,
        'ts': message_ts
    }

    req_url = '{}?{}'.format(DELETE_URL, urllib.parse.urlencode(params))
    req = urllib.request.Request(req_url, headers=headers)
    with urllib.request.urlopen(req) as res:
        data = json.loads(res.read().decode("utf-8"))
        if 'ok' not in data or data['ok'] is not True:
            print('Failed to delete message. ts: {}'.format(message_ts))


def parse(data, tag):
    # parse atom file
    # e.g. Input :<tag>XYZ </tag> -> Output: XYZ

    pattern = "<" + tag + ">([\s\S]*?)<\/" + tag + ">"
    if all:
        obj = re.findall(pattern, data)
    return obj




def search_and_send(query, start, ids, api_url):
    while True:
        counter = 0
        # url of arXiv API
        # If you want to customize, please change here.
        # detail is shown here, https://arxiv.org/help/api/user-manual
        url = 'http://export.arxiv.org/api/query?search_query=submittedDate:[' + previousdate.strftime(
            '%Y%m%d') + '0000+TO+' + basedate.strftime('%Y%m%d') + '0000]+AND+' + query
        # Get returned value from arXiv API
        data = requests.get(url).text
        # Parse the returned value
        entries = parse(data, "entry")
        for entry in entries:
            # Parse each entry
            url = parse(entry, "id")[0]
            #print(url)
            
            if not(url in ids):
                title = parse(entry, "title")[0]
                # abstract = parse(entry, "summary")[0]
                date = parse(entry, "published")[0]
                #post to slack
                message = "\n".join(["=" * 10, "No." + str(counter + 1), "Title:  " + title, "URL: " + url, "Published: " + date])
                requests.post(api_url, json={"text": message})
                #translation by gummy
                translate_journal([str(url), '-pdf',passes.savefolder+title +'.pdf']) #save in passes.py
            
                
                ids.append(url)
                counter = counter + 1
                #if counter == 10:
                if counter == 10: # 10 articles a day
                    return 0
        if counter == 0 and len(entries) < 100:
            requests.post(api_url, json={"text": "Currently, there is no available papers"})
            return 0
        elif counter == 0 and len(entries) == 100:
            # When there is no available paper and full query
            start = start + 100


if __name__ == "__main__":
    basedate = datetime.date.today()
    previousdate = basedate + datetime.timedelta(days=-5)
    print("Publish")
    # Set URL of API
    # Please change here
    api_url = passes.api_url_slack #save in passes.py
    # Load log of published data
    if os.path.exists("published.pkl"):
        ids = pickle.load(open("published.pkl",'rb'))
    else:
        ids = []
    # Query for arXiv API
    # Please change here
    query = "((abs:spin-orbit torque)+OR+(abs:spin-torque)" + \
           "+OR+(abs:orbital Hall)+ OR + (abs:spintronics)+ OR + (abs:Rashba-Edelstein)" \
            "+ OR + (abs:spin Hall)+ OR + (abs:Rashba))"    
    #query = "(abs:spin-orbit torque)"
    start = 0
    # Post greeting to your Slack
    requests.post(api_url, json={"text": "Hello!!"})
    # Call function
    search_and_send(query, start, ids, api_url)
    # Update log of published data
    pickle.dump(ids, open("published.pkl", "wb"))
    
    clean_old_message(passes.channelid) #delete privious posts  #save in passes.py
# Out:
# failed to find libmagic, so use mimetypes instead.
# [success] local driver can be built.
# [failure] remote driver can't be built.
# DRIVER_TYPE: local
# Publish
# Estimated Journal Type : arXiv
# Crawling Type: pdf
# HTTP Error 404: Not Found : url=https://arxiv.org/pdf/http://arxiv.org/abs/2102.05837v1.pdf
# Try to download using webdriver (Open Browser)
# Downloading PDF from https://arxiv.org/pdf/http://arxiv.org/abs/2102.05837v1.pdf
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py", line 256, in download_PDF_with_driver
#     driver.get(url)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py", line 79, in request
#     return self.request_encode_body(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py", line 171, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py", line 336, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/http/client.py", line 1347, in getresponse
#     response.begin()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-fb38920f645a>", line 150, in <module>
#     search_and_send(query, start, ids, api_url)
#   File "<ipython-input-1-fb38920f645a>", line 113, in search_and_send
#     translate_journal([str(url), '-pdf',savefolder+title +'.pdf'])
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/cli.py", line 98, in translate_journal
#     pdf_path = model.toPDF(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py", line 181, in toPDF
#     htmlpath = self.toHTML(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py", line 139, in toHTML
#     title, contents = self.get_contents(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py", line 117, in get_contents
#     title, texts = crawler.get_contents(url=url, driver=self.driver, crawl_type=crawl_type, **gatewaykwargs)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py", line 159, in get_contents
#     title, contents = get_contents_func(url=url, driver=driver, **gatewaykwargs)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py", line 473, in get_contents_pdf
#     pdf_pages = self.get_pdf_source(url=self.get_pdf_url(url), driver=driver)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py", line 493, in get_pdf_source
#     pdf_pages = get_pdf_contents(file=url)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/pdf_utils.py", line 78, in get_pdf_contents
#     with get_pdf_pages(file=file, dirname=dirname) as pages:
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/pdf_utils.py", line 31, in get_pdf_pages
#     path = download_file(url=file, dirname=dirname)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/download_utils.py", line 127, in download_file
#     path = download_PDF_with_driver(url=url, dirname=dirname, verbose=verbose)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py", line 261, in download_PDF_with_driver
#     break
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 170, in __exit__
#     self.quit()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py", line 158, in quit
#     self.service.stop()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/service.py", line 151, in stop
#     self.send_remote_shutdown_command()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/service.py", line 127, in send_remote_shutdown_command
#     url_request.urlopen("%s/shutdown" % self.service_url)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 640, in http_response
#     response = self.parent.error(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 563, in error
#     result = self._call_chain(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 755, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 640, in http_response
#     response = self.parent.error(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 563, in error
#     result = self._call_chain(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 755, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 640, in http_response
#     response = self.parent.error(
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 563, in error
#     result = self._call_chain(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/urllib/request.py", line 752, in http_error_302
#     fp.read()
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/http/client.py", line 471, in read
#     s = self._safe_read(self.length)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/http/client.py", line 612, in _safe_read
#     data = self.fp.read(amt)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/hakureishi/opt/anaconda3/lib/python3.8/posixpath.py", line 52, in normcase
#     def normcase(s):
# KeyboardInterrupt
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py in download_PDF_with_driver(url, dirname, verbose, timeout)
#     255     with get_driver(chrome_options=chrome_options) as driver:
# --> 256         driver.get(url)
#     257         for _ in range(timeout):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-1-fb38920f645a> in <module>
#     149     # Call function
# --> 150     search_and_send(query, start, ids, api_url)
#     151     # Update log of published data
#
# <ipython-input-1-fb38920f645a> in search_and_send(query, start, ids, api_url)
#     112                 savefolder = '/Users/hakureishi/Google ドライブ/gummyPaper/'
# --> 113                 translate_journal([str(url), '-pdf',savefolder+title +'.pdf'])
#     114
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/cli.py in translate_journal(argv)
#      97     )
# ---> 98     pdf_path = model.toPDF(
#      99         url=url, path=pdf_path, out_dir=out_dir, correspond=correspond,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py in toPDF(self, url, path, out_dir, from_lang, to_lang, correspond, journal_type, crawl_type, gateway, searchpath, template, delete_html, options, **gatewaykwargs)
#     180         """
# --> 181         htmlpath = self.toHTML(
#     182             url=url, path=path, out_dir=out_dir,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py in toHTML(self, url, path, out_dir, from_lang, to_lang, correspond, journal_type, crawl_type, gateway, searchpath, template, **gatewaykwargs)
#     138         """
# --> 139         title, contents = self.get_contents(
#     140             url=url, journal_type=journal_type, crawl_type=crawl_type,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/models.py in get_contents(self, url, journal_type, crawl_type, gateway, **gatewaykwargs)
#     116         crawler = journals.get(journal_type, gateway=gateway, sleep_for_loading=3, verbose=self.verbose)
# --> 117         title, texts = crawler.get_contents(url=url, driver=self.driver, crawl_type=crawl_type, **gatewaykwargs)
#     118         return title, texts
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py in get_contents(self, url, driver, crawl_type, **gatewaykwargs)
#     158         get_contents_func = getattr(self, f"get_contents_{crawl_type}")
# --> 159         title, contents = get_contents_func(url=url, driver=driver, **gatewaykwargs)
#     160         return (title, contents)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py in get_contents_pdf(self, url, driver)
#     472         """
# --> 473         pdf_pages = self.get_pdf_source(url=self.get_pdf_url(url), driver=driver)
#     474         title = self.get_title_from_pdf(pdf_pages)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/journals.py in get_pdf_source(self, url, driver)
#     492         """
# --> 493         pdf_pages = get_pdf_contents(file=url)
#     494         return pdf_pages
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/pdf_utils.py in get_pdf_contents(file, dirname)
#      77     pdf_pages = []
# ---> 78     with get_pdf_pages(file=file, dirname=dirname) as pages:
#      79         for page in pages:
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/pdf_utils.py in get_pdf_pages(file, dirname)
#      30         if isinstance(file, str) and (not os.path.exists(file)):
# ---> 31             path = download_file(url=file, dirname=dirname)
#      32             if path is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/download_utils.py in download_file(url, dirname, path, bar_width, verbose)
#     126         try:
# --> 127             path = download_PDF_with_driver(url=url, dirname=dirname, verbose=verbose)
#     128         except urllib.error.URLError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gummy/utils/driver_utils.py in download_PDF_with_driver(url, dirname, verbose, timeout)
#     260             if not path.endswith(".crdownload"):
# --> 261                 break
#     262     if verbose: print(f"Save PDF at {toBLUE(path)}")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __exit__(self, *args)
#     169     def __exit__(self, *args):
# --> 170         self.quit()
#     171
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py in quit(self)
#     157         finally:
# --> 158             self.service.stop()
#     159
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/service.py in stop(self)
#     150         try:
# --> 151             self.send_remote_shutdown_command()
#     152         except TypeError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/service.py in send_remote_shutdown_command(self)
#     126         try:
# --> 127             url_request.urlopen("%s/shutdown" % self.service_url)
#     128         except URLError:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     751         # with HTTPError.
# --> 752         fp.read()
#     753         fp.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     470                 try:
# --> 471                     s = self._safe_read(self.length)
#     472                 except IncompleteRead:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _safe_read(self, amt)
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                         stb = value._render_traceback_()
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
import passes

# %%
API_TOKEN
# Out:
# 'xoxp-27788524001-32435902503-1775464024784-0ed1c56f84b7213867868587d761bb25'

# %%
channel
